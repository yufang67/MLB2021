# %%
import numpy as np
import pandas as pd
from pathlib import Path
#from sklearn.metrics import mean_absolute_error
from datetime import timedelta
#from functools import reduce
#from tqdm import tqdm
#import lightgbm as lgbm
#import mlb
import os
import gc
#import joblib
#import shap
#from shapash.explainer.smart_explainer import SmartExplainer
import missingno as msno

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#from sklearn.metrics import mean_squared_error,r2_score,mean_squared_log_error,mean_absolute_error
#from sklearn.metrics import make_scorer
#from sklearn.model_selection import cross_val_score,cross_validate

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
#np.set_printoptions(threshold=1000)
pd.options.display.max_info_columns=1000

TRAIN_DIR = Path('../data')

# %%
targets_game = pd.read_csv(TRAIN_DIR/'targets_game.csv')
targets_nogame = pd.read_csv(TRAIN_DIR/'targets_nogame.csv')

# %%
#targets_game['id'] = targets_game['gamePk'].astype(str)+'_'+targets_game['date'].astype(str)
targets_game.tail(10)
#targets_game.homeWins_x.unique()
#targets_game['gamePk'].dtype, len(targets_game)
#len(targets_game.columns.tolist())
# Out:
#     3.0                2.0
# 137245          5.0            5.0              0.0                3.0
# 137246          3.0            7.0              1.0                1.0
# 137247          3.0            7.0              2.0                0.0
# 137248          6.0            4.0              1.0                0.0
# 137249          3.0            7.0              2.0                0.0
# 137250          6.0            4.0              1.0                3.0
#
#         oneRunWins  oneRunLosses  dayWins  dayLosses  nightWins  nightLosses  \
# 137241         5.0           5.0      4.0        7.0        8.0          7.0
# 137242         2.0           3.0      4.0        5.0       10.0          7.0
# 137243         4.0           3.0      5.0        3.0       10.0          9.0
# 137244         3.0           3.0      4.0        8.0        8.0          5.0
# 137245         5.0           5.0      4.0        7.0        8.0          7.0
# ...
